# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshay-879/Data-Science/blob/main/06/Copy_of_CS480_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CS480_w.png](data:image/png;base64,...)
# #Assignment 6

# %%
# In this assignment, we will train a U-Net classifer to detect mitochondria
# in electron microscopy images!

# %%
### IMPORTANT ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# load numpy and matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# load the unet tensorflow code
# !pip install git+https://github.com/jakeret/unet.git
# Out:
# Collecting git+https://github.com/jakeret/unet.git
#   Cloning https://github.com/jakeret/unet.git to /tmp/pip-req-build-sa8bn3gb
#   Running command git clone -q https://github.com/jakeret/unet.git /tmp/pip-req-build-sa8bn3gb
# Building wheels for collected packages: unet
#   Building wheel for unet (setup.py) ... done
#   Created wheel for unet: filename=unet-0.0.post0.dev81+gf557a51-py2.py3-none-any.whl size=25688 sha256=d13b50a50e3bf470e70602c2a61ea50ba752983593c31445f2a83ca0147fa991
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qa_y1s0o/wheels/22/00/93/ce57529ed355f160088cbb6ce086e55168770913b40cf624ba
# Successfully built unet
# Installing collected packages: unet
# Successfully installed unet-0.0.post0.dev81+gf557a51

# %%
# .. and use it!
# Note: There are a ton of U-Net implementations but this one is easier to use!
import unet

# %% [markdown]
# **Task 1**: Study the unet circle example and learn about mitochondria! [15 Points]

# %%
# The unet package allows to train a U-Net classifier with little code.
# As discussed in class, the U-Net can be used to label/segment/annotate images.

# %%
# TODO: Please study the Circles example 
# https://github.com/jakeret/unet/blob/master/notebooks/circles.ipynb

# %%
# TODO: ... and look how the (artificial) dataset is generated
# https://github.com/jakeret/unet/blob/master/src/unet/datasets/circles.py

# %%
# 1) Question
# TODO: Please describe what the U-Net is trained to do.
#
# TODO: YOUR ANSWER

# %% [markdown]
# The unet is trained to identify circles in an unfiltered noisy image. The unet can also be trained to detect radio frequency interface(RFI) in radio astronomy and to detect galaxies and star in wide field imaging data.

# %%
# 2) Question
# TODO: In circles.py, what does the following mean:
#     channels = 1
#     classes = 2
#
# TODO: YOUR ANSWER

# %% [markdown]
# The channel parameter denotes the number of channels (layers) in an input image. For example in RGB image  of size 6x4x3, 6 is the height, 4 is wdith and 3 corresponds to the number of channels in the image, i.e, the 'R', 'G' and 'B' channels(layers). In our example our channel value is '1' which means we are processing gray scale images. Using channel = 1, we are storing our images as 3D arrays.
#
#
# The classes in the circles.py indicates the lables or the number of classification the unet is going to perform. Here 2 classes means the unet is going to classify the patters in the images as 1. circles and 2. not circles.

# %%
# 3) Question
# TODO: What are mitochondria and what is their appearance in
# electron microscopy data?
# Hint: You can validate your answer in Task 4!
#
# TODO: YOUR ANSWER

# %% [markdown]
# Mitochondria is a double-membrane organelle found in most cells. It the part of the cell where the cell's respiration and energy production occures. Under a electron micro-scope, a mitochondria appear as rounded or sausage-shaped structures.

# %% [markdown]
# **Task 2**: Setup a datagenerator for mitochondria images! [45 Points]

# %%
# TODO: 
# Download https://cs480.org/data/mito.npz to your computer.
# Then, please upload mito.npz using the file panel on the left.

# %%
# The code below is similar to the circles.py file from Task 1.
# We follow Tensorflow conventions to design a tf.data.Dataset for training
# the U-Net.
#
# TODO: Please add four different data augmentation methods in the code block
# below. (image normalization to 0..1, horizontal data flip, vertical data flip,
# rotation by 90 degrees)
#
# Hint: https://github.com/jakeret/unet/blob/master/src/unet/datasets/oxford_iiit_pet.py#L25

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow_datasets.core import DatasetInfo
from typing import Tuple, List
import numpy as np

IMAGE_SIZE = (256, 256)
channels = 1
classes = 2

def load_data(count:int, splits:Tuple[float]=(0.7, 0.2, 0.1), **kwargs) -> List[tf.data.Dataset]:
    return [tf.data.Dataset.from_tensor_slices(_build_samples(int(split * count), **kwargs))
            for split in splits]


def _build_samples(sample_count:int, **kwargs) -> Tuple[np.array, np.array]:

    # here we load the mitochondria data
    loaded = np.load('mito.npz')
    loadedimages = loaded['arr_0'][0].copy()
    loadedmasks = loaded['arr_0'][1].copy()

    # now let's go to numpyland
    images = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 1))
    labels = np.empty((sample_count, IMAGE_SIZE[0], IMAGE_SIZE[1], 2))
    for i in range(sample_count):
        image, mask = loadedimages[i], loadedmasks[i]

        image = image.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1)).astype(np.float)
        mask = mask.reshape((IMAGE_SIZE[0], IMAGE_SIZE[1], 1))

        #
        # TODO: Normalize the image to 0..1
        #
        # TODO: YOUR CODE
        image = tf.cast(image, tf.float32) / 255.0
        mask -= 1
        #
        # TODO: Use Tensorflow to flip the image horizontally
        #
        if tf.random.uniform(()) > 0.5:
          
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_left_right(image)
            mask = tf.image.flip_left_right(mask)

        #
        # TODO: Use Tensorflow to flip the image vertically
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.flip_up_down(image)
            mask = tf.image.flip_up_down(mask)

        #
        # TODO: Use Tensorflow to rotate the image 90 degrees
        #
        if tf.random.uniform(()) > 0.5:
            #
            # TODO: YOUR CODE
            #
            image = tf.image.rot90(image)
            mask = tf.image.rot90(mask)


        # augmentation done, let's store the image
        images[i] = image

        # here we split the mask to background and foreground
        fg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        fg[mask == 255] = 1
        bg = np.zeros((IMAGE_SIZE[0], IMAGE_SIZE[1], 1), dtype=np.bool)
        bg[mask == 0] = 1
        
        labels[i, :, :, 0] = bg[:,:,0]
        labels[i, :, :, 1] = fg[:,:,0]

    return images, labels

# %% [markdown]
# **Task 3**: Let's train the U-Net! [25 Points]

# %%
#
# We can now create our training, validation, and testing data by calling
# our methods from Task 2.
#
train, val, test = load_data( 660, splits=(0.7, 0.2, 0.1) )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:74: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:76: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# 1) Question
# TODO: We have in total 660 images + 660 masks. Based on the code above,
# how many images are used for training alone?
#
# TODO: YOUR ANSWER

# %% [markdown]
# We have used 70% for our total data set for traning, i.e, we have used 462 images out of total 660 images for training purposes.

# %%
#
# Let's setup the U-Net!
#
LEARNING_RATE = 1e-3

unet_model = unet.build_model(channels=channels,
                              num_classes=classes,
                              layer_depth=5,
                              filters_root=64,
                              padding="same")

unet.finalize_model(unet_model, learning_rate=LEARNING_RATE)

# %%
#
# And, let's setup the trainer...
#
trainer = unet.Trainer(checkpoint_callback=False,
                       learning_rate_scheduler=unet.SchedulerType.WARMUP_LINEAR_DECAY,
                       warmup_proportion=0.1,
                       learning_rate=LEARNING_RATE)

# %%
#
# ...and train the U-Net for 50 epochs with a batch_size of 10!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use training and validation data.
# Hint 2: This will take roughly 30 minutes!
#

#
# TODO: YOUR CODE
#
#
trainer.fit(unet_model, train, val, epochs = 50, batch_size= 10)
# Out:
# Epoch 1/50
# 47/47 [==============================] - 88s 2s/step - loss: 0.4881 - categorical_crossentropy: 0.4881 - categorical_accuracy: 0.6575 - mean_iou: 0.2870 - dice_coefficient: 0.5820 - auc: 0.8151 - learning_rate: 9.9911e-05 - val_loss: 0.2528 - val_categorical_crossentropy: 0.2528 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3661 - val_dice_coefficient: 0.7425 - val_auc: 0.9937
# Epoch 2/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.1097 - categorical_crossentropy: 0.1097 - categorical_accuracy: 0.9115 - mean_iou: 0.4135 - dice_coefficient: 0.8522 - auc: 0.9724 - learning_rate: 2.9991e-04 - val_loss: 0.2870 - val_categorical_crossentropy: 0.2870 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3538 - val_dice_coefficient: 0.7161 - val_auc: 0.9937
# Epoch 3/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.1089 - categorical_crossentropy: 0.1089 - categorical_accuracy: 0.9115 - mean_iou: 0.4114 - dice_coefficient: 0.8491 - auc: 0.9699 - learning_rate: 4.9991e-04 - val_loss: 0.1801 - val_categorical_crossentropy: 0.1801 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.3946 - val_dice_coefficient: 0.8024 - val_auc: 0.9933
# Epoch 4/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.1023 - categorical_crossentropy: 0.1023 - categorical_accuracy: 0.9115 - mean_iou: 0.4144 - dice_coefficient: 0.8562 - auc: 0.9696 - learning_rate: 6.9991e-04 - val_loss: 0.1234 - val_categorical_crossentropy: 0.1234 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4178 - val_dice_coefficient: 0.8520 - val_auc: 0.9933
# Epoch 5/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.1003 - categorical_crossentropy: 0.1003 - categorical_accuracy: 0.9115 - mean_iou: 0.4152 - dice_coefficient: 0.8574 - auc: 0.9710 - learning_rate: 8.9991e-04 - val_loss: 0.1444 - val_categorical_crossentropy: 0.1444 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4096 - val_dice_coefficient: 0.8337 - val_auc: 0.9936
# Epoch 6/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.0996 - categorical_crossentropy: 0.0996 - categorical_accuracy: 0.9115 - mean_iou: 0.4158 - dice_coefficient: 0.8581 - auc: 0.9725 - learning_rate: 9.8890e-04 - val_loss: 0.1429 - val_categorical_crossentropy: 0.1429 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4107 - val_dice_coefficient: 0.8355 - val_auc: 0.9938
# Epoch 7/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.0955 - categorical_crossentropy: 0.0955 - categorical_accuracy: 0.9115 - mean_iou: 0.4179 - dice_coefficient: 0.8625 - auc: 0.9735 - learning_rate: 9.6668e-04 - val_loss: 0.1165 - val_categorical_crossentropy: 0.1165 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4218 - val_dice_coefficient: 0.8592 - val_auc: 0.9938
# Epoch 8/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.0919 - categorical_crossentropy: 0.0919 - categorical_accuracy: 0.9115 - mean_iou: 0.4197 - dice_coefficient: 0.8657 - auc: 0.9762 - learning_rate: 9.4445e-04 - val_loss: 0.1150 - val_categorical_crossentropy: 0.1150 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4234 - val_dice_coefficient: 0.8615 - val_auc: 0.9938
# Epoch 9/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.0905 - categorical_crossentropy: 0.0905 - categorical_accuracy: 0.9115 - mean_iou: 0.4209 - dice_coefficient: 0.8674 - auc: 0.9782 - learning_rate: 9.2223e-04 - val_loss: 0.1214 - val_categorical_crossentropy: 0.1214 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4218 - val_dice_coefficient: 0.8570 - val_auc: 0.9940
# Epoch 10/50
# 47/47 [==============================] - 72s 2s/step - loss: 0.0905 - categorical_crossentropy: 0.0905 - categorical_accuracy: 0.9115 - mean_iou: 0.4216 - dice_coefficient: 0.8678 - auc: 0.9794 - learning_rate: 9.0001e-04 - val_loss: 0.1190 - val_categorical_crossentropy: 0.1190 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4235 - val_dice_coefficient: 0.8599 - val_auc: 0.9941
# Epoch 11/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0884 - categorical_crossentropy: 0.0884 - categorical_accuracy: 0.9115 - mean_iou: 0.4229 - dice_coefficient: 0.8702 - auc: 0.9809 - learning_rate: 8.7779e-04 - val_loss: 0.1160 - val_categorical_crossentropy: 0.1160 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4255 - val_dice_coefficient: 0.8634 - val_auc: 0.9942
# Epoch 12/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.0884 - categorical_crossentropy: 0.0884 - categorical_accuracy: 0.9115 - mean_iou: 0.4237 - dice_coefficient: 0.8706 - auc: 0.9829 - learning_rate: 8.5557e-04 - val_loss: 0.1214 - val_categorical_crossentropy: 0.1214 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4247 - val_dice_coefficient: 0.8604 - val_auc: 0.9943
# Epoch 13/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0884 - categorical_crossentropy: 0.0884 - categorical_accuracy: 0.9115 - mean_iou: 0.4245 - dice_coefficient: 0.8713 - auc: 0.9839 - learning_rate: 8.3334e-04 - val_loss: 0.1248 - val_categorical_crossentropy: 0.1248 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4243 - val_dice_coefficient: 0.8587 - val_auc: 0.9944
# Epoch 14/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.0873 - categorical_crossentropy: 0.0873 - categorical_accuracy: 0.9115 - mean_iou: 0.4255 - dice_coefficient: 0.8728 - auc: 0.9849 - learning_rate: 8.1112e-04 - val_loss: 0.1160 - val_categorical_crossentropy: 0.1160 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4284 - val_dice_coefficient: 0.8670 - val_auc: 0.9945
# Epoch 15/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0860 - categorical_crossentropy: 0.0860 - categorical_accuracy: 0.9115 - mean_iou: 0.4267 - dice_coefficient: 0.8743 - auc: 0.9862 - learning_rate: 7.8890e-04 - val_loss: 0.1146 - val_categorical_crossentropy: 0.1146 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4298 - val_dice_coefficient: 0.8692 - val_auc: 0.9946
# Epoch 16/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.0854 - categorical_crossentropy: 0.0854 - categorical_accuracy: 0.9115 - mean_iou: 0.4276 - dice_coefficient: 0.8752 - auc: 0.9871 - learning_rate: 7.6668e-04 - val_loss: 0.1163 - val_categorical_crossentropy: 0.1163 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4296 - val_dice_coefficient: 0.8683 - val_auc: 0.9947
# Epoch 17/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.0836 - categorical_crossentropy: 0.0836 - categorical_accuracy: 0.9115 - mean_iou: 0.4286 - dice_coefficient: 0.8771 - auc: 0.9877 - learning_rate: 7.4445e-04 - val_loss: 0.1073 - val_categorical_crossentropy: 0.1073 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4334 - val_dice_coefficient: 0.8762 - val_auc: 0.9948
# Epoch 18/50
# 47/47 [==============================] - 67s 1s/step - loss: 0.0821 - categorical_crossentropy: 0.0821 - categorical_accuracy: 0.9115 - mean_iou: 0.4299 - dice_coefficient: 0.8786 - auc: 0.9888 - learning_rate: 7.2223e-04 - val_loss: 0.1158 - val_categorical_crossentropy: 0.1158 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4308 - val_dice_coefficient: 0.8699 - val_auc: 0.9950
# Epoch 19/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0824 - categorical_crossentropy: 0.0824 - categorical_accuracy: 0.9115 - mean_iou: 0.4300 - dice_coefficient: 0.8787 - auc: 0.9888 - learning_rate: 7.0001e-04 - val_loss: 0.0997 - val_categorical_crossentropy: 0.0997 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4368 - val_dice_coefficient: 0.8832 - val_auc: 0.9950
# Epoch 20/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0801 - categorical_crossentropy: 0.0801 - categorical_accuracy: 0.9115 - mean_iou: 0.4314 - dice_coefficient: 0.8809 - auc: 0.9897 - learning_rate: 6.7779e-04 - val_loss: 0.0991 - val_categorical_crossentropy: 0.0991 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4372 - val_dice_coefficient: 0.8839 - val_auc: 0.9952
# Epoch 21/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0783 - categorical_crossentropy: 0.0783 - categorical_accuracy: 0.9115 - mean_iou: 0.4323 - dice_coefficient: 0.8824 - auc: 0.9901 - learning_rate: 6.5557e-04 - val_loss: 0.1038 - val_categorical_crossentropy: 0.1038 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4360 - val_dice_coefficient: 0.8806 - val_auc: 0.9953
# Epoch 22/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0790 - categorical_crossentropy: 0.0790 - categorical_accuracy: 0.9115 - mean_iou: 0.4324 - dice_coefficient: 0.8823 - auc: 0.9903 - learning_rate: 6.3334e-04 - val_loss: 0.0907 - val_categorical_crossentropy: 0.0907 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4406 - val_dice_coefficient: 0.8911 - val_auc: 0.9953
# Epoch 23/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0758 - categorical_crossentropy: 0.0758 - categorical_accuracy: 0.9115 - mean_iou: 0.4338 - dice_coefficient: 0.8850 - auc: 0.9909 - learning_rate: 6.1112e-04 - val_loss: 0.0885 - val_categorical_crossentropy: 0.0885 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4417 - val_dice_coefficient: 0.8931 - val_auc: 0.9954
# Epoch 24/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0749 - categorical_crossentropy: 0.0749 - categorical_accuracy: 0.9115 - mean_iou: 0.4345 - dice_coefficient: 0.8860 - auc: 0.9912 - learning_rate: 5.8890e-04 - val_loss: 0.0858 - val_categorical_crossentropy: 0.0858 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4429 - val_dice_coefficient: 0.8955 - val_auc: 0.9955
# Epoch 25/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0735 - categorical_crossentropy: 0.0735 - categorical_accuracy: 0.9115 - mean_iou: 0.4352 - dice_coefficient: 0.8873 - auc: 0.9915 - learning_rate: 5.6668e-04 - val_loss: 0.0841 - val_categorical_crossentropy: 0.0841 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4437 - val_dice_coefficient: 0.8971 - val_auc: 0.9955
# Epoch 26/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0730 - categorical_crossentropy: 0.0730 - categorical_accuracy: 0.9115 - mean_iou: 0.4357 - dice_coefficient: 0.8879 - auc: 0.9917 - learning_rate: 5.4445e-04 - val_loss: 0.0812 - val_categorical_crossentropy: 0.0812 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4449 - val_dice_coefficient: 0.8996 - val_auc: 0.9956
# Epoch 27/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0718 - categorical_crossentropy: 0.0718 - categorical_accuracy: 0.9115 - mean_iou: 0.4364 - dice_coefficient: 0.8890 - auc: 0.9919 - learning_rate: 5.2223e-04 - val_loss: 0.0789 - val_categorical_crossentropy: 0.0789 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4459 - val_dice_coefficient: 0.9016 - val_auc: 0.9956
# Epoch 28/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0711 - categorical_crossentropy: 0.0711 - categorical_accuracy: 0.9115 - mean_iou: 0.4369 - dice_coefficient: 0.8898 - auc: 0.9921 - learning_rate: 5.0001e-04 - val_loss: 0.0771 - val_categorical_crossentropy: 0.0771 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4468 - val_dice_coefficient: 0.9033 - val_auc: 0.9957
# Epoch 29/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0706 - categorical_crossentropy: 0.0706 - categorical_accuracy: 0.9115 - mean_iou: 0.4374 - dice_coefficient: 0.8904 - auc: 0.9923 - learning_rate: 4.7779e-04 - val_loss: 0.0752 - val_categorical_crossentropy: 0.0752 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4476 - val_dice_coefficient: 0.9050 - val_auc: 0.9957
# Epoch 30/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0702 - categorical_crossentropy: 0.0702 - categorical_accuracy: 0.9115 - mean_iou: 0.4378 - dice_coefficient: 0.8909 - auc: 0.9924 - learning_rate: 4.5557e-04 - val_loss: 0.0735 - val_categorical_crossentropy: 0.0735 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4484 - val_dice_coefficient: 0.9065 - val_auc: 0.9957
# Epoch 31/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0697 - categorical_crossentropy: 0.0697 - categorical_accuracy: 0.9115 - mean_iou: 0.4382 - dice_coefficient: 0.8914 - auc: 0.9926 - learning_rate: 4.3334e-04 - val_loss: 0.0720 - val_categorical_crossentropy: 0.0720 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4491 - val_dice_coefficient: 0.9079 - val_auc: 0.9958
# Epoch 32/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0694 - categorical_crossentropy: 0.0694 - categorical_accuracy: 0.9115 - mean_iou: 0.4385 - dice_coefficient: 0.8918 - auc: 0.9927 - learning_rate: 4.1112e-04 - val_loss: 0.0706 - val_categorical_crossentropy: 0.0706 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4497 - val_dice_coefficient: 0.9091 - val_auc: 0.9958
# Epoch 33/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0689 - categorical_crossentropy: 0.0689 - categorical_accuracy: 0.9115 - mean_iou: 0.4389 - dice_coefficient: 0.8923 - auc: 0.9928 - learning_rate: 3.8890e-04 - val_loss: 0.0701 - val_categorical_crossentropy: 0.0701 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4500 - val_dice_coefficient: 0.9096 - val_auc: 0.9958
# Epoch 34/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0663 - categorical_crossentropy: 0.0663 - categorical_accuracy: 0.9126 - mean_iou: 0.4402 - dice_coefficient: 0.8945 - auc: 0.9930 - learning_rate: 3.6668e-04 - val_loss: 0.0882 - val_categorical_crossentropy: 0.0882 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4435 - val_dice_coefficient: 0.8947 - val_auc: 0.9960
# Epoch 35/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0697 - categorical_crossentropy: 0.0697 - categorical_accuracy: 0.9116 - mean_iou: 0.4388 - dice_coefficient: 0.8917 - auc: 0.9930 - learning_rate: 3.4445e-04 - val_loss: 0.0735 - val_categorical_crossentropy: 0.0735 - val_categorical_accuracy: 0.9434 - val_mean_iou: 0.4497 - val_dice_coefficient: 0.9078 - val_auc: 0.9959
# Epoch 36/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0656 - categorical_crossentropy: 0.0656 - categorical_accuracy: 0.9206 - mean_iou: 0.4413 - dice_coefficient: 0.8955 - auc: 0.9933 - learning_rate: 3.2223e-04 - val_loss: 0.0953 - val_categorical_crossentropy: 0.0953 - val_categorical_accuracy: 0.9364 - val_mean_iou: 0.4433 - val_dice_coefficient: 0.8916 - val_auc: 0.9948
# Epoch 37/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0641 - categorical_crossentropy: 0.0641 - categorical_accuracy: 0.9294 - mean_iou: 0.4424 - dice_coefficient: 0.8968 - auc: 0.9934 - learning_rate: 3.0001e-04 - val_loss: 0.1180 - val_categorical_crossentropy: 0.1180 - val_categorical_accuracy: 0.9016 - val_mean_iou: 0.4369 - val_dice_coefficient: 0.8761 - val_auc: 0.9901
# Epoch 38/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0613 - categorical_crossentropy: 0.0613 - categorical_accuracy: 0.9415 - mean_iou: 0.4464 - dice_coefficient: 0.9006 - auc: 0.9936 - learning_rate: 2.7779e-04 - val_loss: 0.1071 - val_categorical_crossentropy: 0.1071 - val_categorical_accuracy: 0.8851 - val_mean_iou: 0.4430 - val_dice_coefficient: 0.8867 - val_auc: 0.9870
# Epoch 39/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0476 - categorical_crossentropy: 0.0476 - categorical_accuracy: 0.9444 - mean_iou: 0.4539 - dice_coefficient: 0.9135 - auc: 0.9943 - learning_rate: 2.5557e-04 - val_loss: 0.0829 - val_categorical_crossentropy: 0.0829 - val_categorical_accuracy: 0.9143 - val_mean_iou: 0.4516 - val_dice_coefficient: 0.9044 - val_auc: 0.9917
# Epoch 40/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0429 - categorical_crossentropy: 0.0429 - categorical_accuracy: 0.9467 - mean_iou: 0.4559 - dice_coefficient: 0.9174 - auc: 0.9951 - learning_rate: 2.3334e-04 - val_loss: 0.1062 - val_categorical_crossentropy: 0.1062 - val_categorical_accuracy: 0.8828 - val_mean_iou: 0.4437 - val_dice_coefficient: 0.8880 - val_auc: 0.9866
# Epoch 41/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0417 - categorical_crossentropy: 0.0417 - categorical_accuracy: 0.9482 - mean_iou: 0.4567 - dice_coefficient: 0.9185 - auc: 0.9953 - learning_rate: 2.1112e-04 - val_loss: 0.1019 - val_categorical_crossentropy: 0.1019 - val_categorical_accuracy: 0.8953 - val_mean_iou: 0.4450 - val_dice_coefficient: 0.8908 - val_auc: 0.9888
# Epoch 42/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0424 - categorical_crossentropy: 0.0424 - categorical_accuracy: 0.9453 - mean_iou: 0.4561 - dice_coefficient: 0.9179 - auc: 0.9954 - learning_rate: 1.8890e-04 - val_loss: 0.0772 - val_categorical_crossentropy: 0.0772 - val_categorical_accuracy: 0.9261 - val_mean_iou: 0.4540 - val_dice_coefficient: 0.9090 - val_auc: 0.9933
# Epoch 43/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0415 - categorical_crossentropy: 0.0415 - categorical_accuracy: 0.9507 - mean_iou: 0.4569 - dice_coefficient: 0.9190 - auc: 0.9959 - learning_rate: 1.6668e-04 - val_loss: 0.0533 - val_categorical_crossentropy: 0.0533 - val_categorical_accuracy: 0.9495 - val_mean_iou: 0.4626 - val_dice_coefficient: 0.9271 - val_auc: 0.9963
# Epoch 44/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0348 - categorical_crossentropy: 0.0348 - categorical_accuracy: 0.9573 - mean_iou: 0.4604 - dice_coefficient: 0.9250 - auc: 0.9967 - learning_rate: 1.4445e-04 - val_loss: 0.0680 - val_categorical_crossentropy: 0.0680 - val_categorical_accuracy: 0.9415 - val_mean_iou: 0.4569 - val_dice_coefficient: 0.9154 - val_auc: 0.9953
# Epoch 45/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0276 - categorical_crossentropy: 0.0276 - categorical_accuracy: 0.9663 - mean_iou: 0.4632 - dice_coefficient: 0.9303 - auc: 0.9978 - learning_rate: 1.2223e-04 - val_loss: 0.0614 - val_categorical_crossentropy: 0.0614 - val_categorical_accuracy: 0.9478 - val_mean_iou: 0.4593 - val_dice_coefficient: 0.9203 - val_auc: 0.9960
# Epoch 46/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0258 - categorical_crossentropy: 0.0258 - categorical_accuracy: 0.9687 - mean_iou: 0.4640 - dice_coefficient: 0.9318 - auc: 0.9980 - learning_rate: 1.0001e-04 - val_loss: 0.0639 - val_categorical_crossentropy: 0.0639 - val_categorical_accuracy: 0.9464 - val_mean_iou: 0.4583 - val_dice_coefficient: 0.9184 - val_auc: 0.9959
# Epoch 47/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0240 - categorical_crossentropy: 0.0240 - categorical_accuracy: 0.9706 - mean_iou: 0.4649 - dice_coefficient: 0.9333 - auc: 0.9982 - learning_rate: 7.7788e-05 - val_loss: 0.0576 - val_categorical_crossentropy: 0.0576 - val_categorical_accuracy: 0.9524 - val_mean_iou: 0.4606 - val_dice_coefficient: 0.9231 - val_auc: 0.9965
# Epoch 48/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0228 - categorical_crossentropy: 0.0228 - categorical_accuracy: 0.9719 - mean_iou: 0.4655 - dice_coefficient: 0.9343 - auc: 0.9983 - learning_rate: 5.5565e-05 - val_loss: 0.0596 - val_categorical_crossentropy: 0.0596 - val_categorical_accuracy: 0.9506 - val_mean_iou: 0.4599 - val_dice_coefficient: 0.9216 - val_auc: 0.9963
# Epoch 49/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0220 - categorical_crossentropy: 0.0220 - categorical_accuracy: 0.9727 - mean_iou: 0.4658 - dice_coefficient: 0.9350 - auc: 0.9983 - learning_rate: 3.3343e-05 - val_loss: 0.0704 - val_categorical_crossentropy: 0.0704 - val_categorical_accuracy: 0.9408 - val_mean_iou: 0.4559 - val_dice_coefficient: 0.9135 - val_auc: 0.9952
# Epoch 50/50
# 47/47 [==============================] - 66s 1s/step - loss: 0.0203 - categorical_crossentropy: 0.0203 - categorical_accuracy: 0.9736 - mean_iou: 0.4664 - dice_coefficient: 0.9363 - auc: 0.9985 - learning_rate: 1.1121e-05 - val_loss: 0.0744 - val_categorical_crossentropy: 0.0744 - val_categorical_accuracy: 0.9367 - val_mean_iou: 0.4545 - val_dice_coefficient: 0.9105 - val_auc: 0.9947

# %% [markdown]
# **Task 4**: Let's predict mitochondria in the testing data! [15 Points]

# %%
# 
# After training, let's try the U-Net on our testing data.
#
# The code below displays the first 10 input images, the original masks by experts, 
# and the predicted masks from the U-Net.

# %%
rows = 10
fig, axs = plt.subplots(rows, 3, figsize=(8, 30))
for ax, (image, label) in zip(axs, test.take(rows).batch(1)):
  
  prediction = unet_model.predict(image)
  ax[0].matshow(image[0, :, :, 0])
  ax[1].matshow(label[0, :, :, 1], cmap="gray")
  ax[2].matshow(prediction[0].argmax(axis=-1), cmap="gray")

# %%
# 1) Question
# TODO: Why do we use the prediction[0].argmax(axis=-1) command
# to display the prediction?
# 
# TODO: YOUR ANSWER

# %%
prediction.shape
# Out:
# (10, 256, 256, 2)

# %%
prediction[0].shape
# Out:
# (256, 256, 2)

# %%
prediction[0].argmax(axis = -1).shape
# Out:
# (256, 256)

# %% [markdown]
# unet_model.predict gives us an array of shape (10,256,256,2). The prediction[0] gives us the predicted image array of shape (256,256,2).
#
# The argmax(axis=-1) function in numpy returns us the actual image array of dimension (256,256).

# %%
# 2) Question
# TODO: Is the quality of the segmentation good and how could we improve it?
# Hint: Think along the lines of some traditional image processing rather than
# increasing the training data size.
#
# TODO: YOUR ANSWER

# %% [markdown]
# The qualitiy of the segmentation is good but can be imporved by applying some image pre-processing and image augmentations like:
#
# 1. Converting the images into grayscale images before giving to the model.
#
# 2. Applying some edge detction filters to the pre-processed grayscale images and feeding these images to the unet model
#
# 3. Removing noise from the images before traning of the model etc.

# %% [markdown]
# **Bonus**: Compare against the state-of-the-art literature! [33 Points]

# %%
#
# The following paper also uses a 2D U-Net to detect mitochondria:
# 
# https://danielhaehn.com/papers/?casser2020fast
#

# %%
# 1) Question
#
# TODO: How many learnable parameters does your trained unet_model have?
# Hint: You can use TF's Model Summary function to answer this.
#

# %%
# TODO: YOUR CODE

# %%
unet_model.summary()
# Out:
# Model: "unet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  inputs (InputLayer)            [(None, None, None,  0           []
#                                  1)]
#
#  conv_block (ConvBlock)         (None, None, None,   37568       ['inputs[0][0]']
#                                 64)
#
#  max_pooling2d (MaxPooling2D)   (None, None, None,   0           ['conv_block[0][0]']
#                                 64)
#
#  conv_block_1 (ConvBlock)       (None, None, None,   221440      ['max_pooling2d[0][0]']
#                                 128)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, None, None,   0          ['conv_block_1[0][0]']
#                                 128)
#
#  conv_block_2 (ConvBlock)       (None, None, None,   885248      ['max_pooling2d_1[0][0]']
#                                 256)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, None, None,   0          ['conv_block_2[0][0]']
#                                 256)
#
#  conv_block_3 (ConvBlock)       (None, None, None,   3539968     ['max_pooling2d_2[0][0]']
#                                 512)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, None, None,   0          ['conv_block_3[0][0]']
#                                 512)
#
#  conv_block_4 (ConvBlock)       (None, None, None,   14157824    ['max_pooling2d_3[0][0]']
#                                 1024)
#
#  upconv_block (UpconvBlock)     (None, None, None,   2097664     ['conv_block_4[0][0]']
#                                 512)
#
#  crop_concat_block (CropConcatB  (None, None, None,   0          ['upconv_block[0][0]',
#  lock)                          1024)                             'conv_block_3[0][0]']
#
#  conv_block_5 (ConvBlock)       (None, None, None,   7078912     ['crop_concat_block[0][0]']
#                                 512)
#
#  upconv_block_1 (UpconvBlock)   (None, None, None,   524544      ['conv_block_5[0][0]']
#                                 256)
#
#  crop_concat_block_1 (CropConca  (None, None, None,   0          ['upconv_block_1[0][0]',
#  tBlock)                        512)                              'conv_block_2[0][0]']
#
#  conv_block_6 (ConvBlock)       (None, None, None,   1769984     ['crop_concat_block_1[0][0]']
#                                 256)
#
#  upconv_block_2 (UpconvBlock)   (None, None, None,   131200      ['conv_block_6[0][0]']
#                                 128)
#
#  crop_concat_block_2 (CropConca  (None, None, None,   0          ['upconv_block_2[0][0]',
#  tBlock)                        256)                              'conv_block_1[0][0]']
#
#  conv_block_7 (ConvBlock)       (None, None, None,   442624      ['crop_concat_block_2[0][0]']
#                                 128)
#
#  upconv_block_3 (UpconvBlock)   (None, None, None,   32832       ['conv_block_7[0][0]']
#                                 64)
#
#  crop_concat_block_3 (CropConca  (None, None, None,   0          ['upconv_block_3[0][0]',
#  tBlock)                        128)                              'conv_block[0][0]']
#
#  conv_block_8 (ConvBlock)       (None, None, None,   110720      ['crop_concat_block_3[0][0]']
#                                 64)
#
#  conv2d_18 (Conv2D)             (None, None, None,   130         ['conv_block_8[0][0]']
#                                 2)
#
#  activation_22 (Activation)     (None, None, None,   0           ['conv2d_18[0][0]']
#                                 2)
#
#  outputs (Activation)           (None, None, None,   0           ['activation_22[0][0]']
#                                 2)
#
# ==================================================================================================
# Total params: 31,030,658
# Trainable params: 31,030,658
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# The total lernable parameters in our model are 31,030,658

# %%
# 2) Question
#
# TODO: How many parameters do Casser et al. use?
#

# %%
# TODO: YOUR ANSWER

# %% [markdown]
# Casser et al. used  1,178,480 parameters for the encoder and 780,053 for the decoder, in total he used 1,958,533 parameters.

# %%
# 3) Question
#
# TODO: How did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# %% [markdown]
# Casser et al. reduced the parameters by:
#
# 1. Reducing the number of convolutional filters throughout the network.
#
# 2. Replacing the transpose convolutions in the decoder with light-weight bilinear upsampling layers.
#
# 3. Replacing center-cropping from the original U-Net with padding to output densely at full resolution.

# %%
# 4) Question
#
# TODO: Why did Casser et al. reduce the parameters?
#

# %%
# TODO: YOUR ANSWER

# %% [markdown]
# Casser et al. reduced the number of parameters to reduce the processing time and to avoid waiting for computationally expensive pre-alignment
# procedure. Reducing the parameters also resulted in an increase in the throughput of the model by 40%.

# %% [markdown]
# Refrences:
# 1. Google
#
# 2. Tensorflow tf.image documentation: https://www.tensorflow.org/api_docs/python/tf/image
#
# 3. Stackexchange: https://ai.stackexchange.com/questions/27564/what-does-the-number-of-channels-correspond-to-in-u-net

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
